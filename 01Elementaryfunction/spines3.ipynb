# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
X = np.linspace(-np.pi,+np.pi,256)
Y = np.sin(X)

# %%
fig = plt.figure(figsize=(8,6), dpi=72,facecolor="white")
axes = plt.subplot(111)
axes.plot(X,Y, color = 'red', linewidth=1, linestyle="-")
axes.set_xlim(X.min(),X.max())
axes.set_ylim(1.01*Y.min(), 1.01*Y.max())

axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')
axes.xaxis.set_ticks_position('bottom')
axes.spines['bottom'].set_position(('data',0))
axes.yaxis.set_ticks_position('left')
axes.spines['left'].set_position(('data',X.min()))

plt.show()

# %%
# Data to be represented
X = np.linspace(-np.pi,+np.pi,256)
Y = np.sin(X)
fig = plt.figure(figsize=(8,6), dpi=72,facecolor="white")
axes = plt.subplot(111)
axes.plot(X,Y, color = 'blue', linewidth=2, linestyle="-")
axes.set_xlim(X.min(),X.max())
axes.set_ylim(1.01*Y.min(),1.01*Y.max())

# 去掉后边和上边界的线
axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')
# 移动x到y=0
axes.xaxis.set_ticks_position('bottom')
axes.spines['bottom'].set_position(('data',0))
# 移动y到x=0
axes.yaxis.set_ticks_position('left')
axes.spines['left'].set_position(('data',0))

# 设置x/y 在坐标轴上显示的tick
axes.set_xticks([1, 2, 3, 4])
axes.set_yticks([-1, 0, 1])
# Out:
# [<matplotlib.axis.YTick at 0x10ce51890>,
#  <matplotlib.axis.YTick at 0x10cf41850>,
#  <matplotlib.axis.YTick at 0x10cd37550>]
